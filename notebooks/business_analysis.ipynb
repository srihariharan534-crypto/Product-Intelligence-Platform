# %% [markdown]
# # Business Performance & Growth Analysis
#
# This notebook calculates business metrics (Cohort Retention, RFM Customer Segments, Churn, and MRR) and generates analytics-driven insights.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ## 1. Monthly Recurring Revenue (MRR) Trends

# %%
processed_dir = "../data/processed"
df_revenue = pd.read_csv(os.path.join(processed_dir, "monthly_revenue_kpis.csv"))

plt.figure(figsize=(14, 6))
sns.lineplot(data=df_revenue, x="month", y="mrr", marker="o", color="b")
plt.xticks(rotation=45)
plt.title("Monthly Recurring Revenue (MRR) Growth Over Time")
plt.xlabel("Month")
plt.ylabel("MRR ($)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Customer Segmentation Analysis

# %%
df_rfm = pd.read_csv(os.path.join(processed_dir, "customer_rfm.csv"))

plt.figure(figsize=(12, 6))
sns.countplot(data=df_rfm, y="rfm_segment", order=df_rfm["rfm_segment"].value_counts().index, palette="magma")
plt.title("RFM Customer Segment Distribution")
plt.xlabel("Number of Customers")
plt.ylabel("RFM Segment")
plt.show()

# %% [markdown]
# ## 3. Cohort Retention Heatmap

# %%
df_cohort = pd.read_csv(os.path.join(processed_dir, "cohort_retention.csv"), index_col=0)

plt.figure(figsize=(16, 10))
sns.heatmap(df_cohort.iloc[:, :12] * 100, annot=True, fmt=".1f", cmap="YlGnBu", cbar_kws={'label': 'Retention (%)'})
plt.title("Cohort Retention Analysis (Months Since Signup)")
plt.ylabel("Cohort Month")
plt.xlabel("Months Since Signup")
plt.show()
