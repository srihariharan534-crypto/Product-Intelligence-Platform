# %% [markdown]
# # Exploratory Data Analysis (EDA) - Product Intelligence Platform
#
# This notebook performs exploratory analysis on customer demographic profiles, pricing tier sales distribution, and transactions data.
# We analyze dataset characteristics, shapes, distributions, and missing values.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")
# %matplotlib inline

# %% [markdown]
# ## 1. Load Datasets

# %%
raw_dir = "../data/raw"
df_cust = pd.read_csv(os.path.join(raw_dir, "customers.csv"))
df_prod = pd.read_csv(os.path.join(raw_dir, "products.csv"))
df_trans = pd.read_csv(os.path.join(raw_dir, "transactions.csv"))

# %% [markdown]
# ## 2. General Dataset Summaries

# %%
print("=== Customers Shape ===")
print(df_cust.shape)
print("\n=== Products Shape ===")
print(df_prod.shape)
print("\n=== Transactions Shape ===")
print(df_trans.shape)

# %%
df_cust.info()

# %%
df_trans.info()

# %% [markdown]
# ## 3. Customer Demographics Distributions

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
sns.countplot(data=df_cust, x="segment", ax=axes[0], palette="Blues_d")
axes[0].set_title("Customer Segment Distribution")

sns.countplot(data=df_cust, y="country", ax=axes[1], palette="viridis", order=df_cust["country"].value_counts().index)
axes[1].set_title("Customer Country Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Product Sales Values and Volumes

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df_trans, x="amount", kde=True, bins=30)
plt.title("Transaction Amount Distribution")
plt.show()
